# %%
import os
HOME = os.getcwd()
print(f'HOME directory path: \'{HOME}\'')
# Out:
# HOME directory path: '/content'

# %%
# Installing required packages
# !pip install -r {HOME}/requirements.txt # --quiet
# Out:
# Collecting rasterio==1.4.2 (from -r /content/requirements.txt (line 1))
#   Downloading rasterio-1.4.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Collecting ultralytics>=8.3 (from -r /content/requirements.txt (line 2))
#   Downloading ultralytics-8.3.165-py3-none-any.whl.metadata (37 kB)
# Collecting labelme2yolo==0.2.5 (from -r /content/requirements.txt (line 3))
#   Downloading labelme2yolo-0.2.5-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting roboflow==1.1.48 (from -r /content/requirements.txt (line 4))
#   Downloading roboflow-1.1.48-py3-none-any.whl.metadata (9.7 kB)
# Collecting affine (from rasterio==1.4.2->-r /content/requirements.txt (line 1))
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.11/dist-packages (from rasterio==1.4.2->-r /content/requirements.txt (line 1)) (25.3.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from rasterio==1.4.2->-r /content/requirements.txt (line 1)) (2025.7.9)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.11/dist-packages (from rasterio==1.4.2->-r /content/requirements.txt (line 1)) (8.2.1)
# Collecting cligj>=0.5 (from rasterio==1.4.2->-r /content/requirements.txt (line 1))
#   Downloading cligj-0.7.2-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.11/dist-packages (from rasterio==1.4.2->-r /content/requirements.txt (line 1)) (2.0.2)
# Collecting click-plugins (from rasterio==1.4.2->-r /content/requirements.txt (line 1))
#   Downloading click_plugins-1.1.1.2-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.11/dist-packages (from rasterio==1.4.2->-r /content/requirements.txt (line 1)) (3.2.3)
# Collecting idna==3.7 (from roboflow==1.1.48->-r /content/requirements.txt (line 4))
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in /usr/local/lib/python3.11/dist-packages (from roboflow==1.1.48->-r /content/requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from roboflow==1.1.48->-r /content/requirements.txt (line 4)) (1.4.8)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from roboflow==1.1.48->-r /content/requirements.txt (line 4)) (3.10.0)
# Collecting opencv-python-headless==4.10.0.84 (from roboflow==1.1.48->-r /content/requirements.txt (line 4))
#   Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from roboflow==1.1.48->-r /content/requirements.txt (line 4)) (11.2.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from roboflow==1.1.48->-r /content/requirements.txt (line 4)) (2.9.0.post0)
# Collecting python-dotenv (from roboflow==1.1.48->-r /content/requirements.txt (line 4))
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from roboflow==1.1.48->-r /content/requirements.txt (line 4)) (2.32.3)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from roboflow==1.1.48->-r /content/requirements.txt (line 4)) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.11/dist-packages (from roboflow==1.1.48->-r /content/requirements.txt (line 4)) (2.4.0)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from roboflow==1.1.48->-r /content/requirements.txt (line 4)) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from roboflow==1.1.48->-r /content/requirements.txt (line 4)) (6.0.2)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.11/dist-packages (from roboflow==1.1.48->-r /content/requirements.txt (line 4)) (1.0.0)
# Collecting filetype (from roboflow==1.1.48->-r /content/requirements.txt (line 4))
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics>=8.3->-r /content/requirements.txt (line 2)) (4.11.0.86)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics>=8.3->-r /content/requirements.txt (line 2)) (1.15.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics>=8.3->-r /content/requirements.txt (line 2)) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics>=8.3->-r /content/requirements.txt (line 2)) (0.21.0+cu124)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics>=8.3->-r /content/requirements.txt (line 2)) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics>=8.3->-r /content/requirements.txt (line 2)) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics>=8.3->-r /content/requirements.txt (line 2)) (2.2.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics>=8.3->-r /content/requirements.txt (line 2))
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow==1.1.48->-r /content/requirements.txt (line 4)) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow==1.1.48->-r /content/requirements.txt (line 4)) (4.58.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow==1.1.48->-r /content/requirements.txt (line 4)) (24.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics>=8.3->-r /content/requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics>=8.3->-r /content/requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->roboflow==1.1.48->-r /content/requirements.txt (line 4)) (3.4.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics>=8.3->-r /content/requirements.txt (line 2)) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics>=8.3->-r /content/requirements.txt (line 2)) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics>=8.3->-r /content/requirements.txt (line 2)) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics>=8.3->-r /content/requirements.txt (line 2)) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics>=8.3->-r /content/requirements.txt (line 2)) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8.0->ultralytics>=8.3->-r /content/requirements.txt (line 2))
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8.0->ultralytics>=8.3->-r /content/requirements.txt (line 2))
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8.0->ultralytics>=8.3->-r /content/requirements.txt (line 2))
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8.0->ultralytics>=8.3->-r /content/requirements.txt (line 2))
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8.0->ultralytics>=8.3->-r /content/requirements.txt (line 2))
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8.0->ultralytics>=8.3->-r /content/requirements.txt (line 2))
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8.0->ultralytics>=8.3->-r /content/requirements.txt (line 2))
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8.0->ultralytics>=8.3->-r /content/requirements.txt (line 2))
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8.0->ultralytics>=8.3->-r /content/requirements.txt (line 2))
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics>=8.3->-r /content/requirements.txt (line 2)) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics>=8.3->-r /content/requirements.txt (line 2)) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics>=8.3->-r /content/requirements.txt (line 2)) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8.0->ultralytics>=8.3->-r /content/requirements.txt (line 2))
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics>=8.3->-r /content/requirements.txt (line 2)) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics>=8.3->-r /content/requirements.txt (line 2)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics>=8.3->-r /content/requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics>=8.3->-r /content/requirements.txt (line 2)) (3.0.2)
# Downloading rasterio-1.4.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 13.5 MB/s eta 0:00:00
# Downloading labelme2yolo-0.2.5-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 76.7 MB/s eta 0:00:00
# Downloading roboflow-1.1.48-py3-none-any.whl (80 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 8.7 MB/s eta 0:00:00
# Downloading idna-3.7-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.7 MB/s eta 0:00:00
# Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 19.4 MB/s eta 0:00:00
# Downloading ultralytics-8.3.165-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 66.9 MB/s eta 0:00:00
# Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 113.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 91.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 59.3 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 16.9 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 76.2 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Downloading click_plugins-1.1.1.2-py2.py3-none-any.whl (11 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Installing collected packages: filetype, python-dotenv, opencv-python-headless, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, labelme2yolo, idna, cligj, click-plugins, affine, rasterio, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, roboflow, ultralytics-thop, ultralytics
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed affine-2.4.0 click-plugins-1.1.1.2 cligj-0.7.2 filetype-1.2.0 idna-3.7 labelme2yolo-0.2.5 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 opencv-python-headless-4.10.0.84 python-dotenv-1.1.1 rasterio-1.4.2 roboflow-1.1.48 ultralytics-8.3.165 ultralytics-thop-2.0.14

# %%
import roboflow
# roboflow.login(force=True) # Login into roboflow

# %%
import roboflow

YOUR_API_KEY_HERE = '1uJPnKZfiCDGkBOaUtv4'

rf = roboflow.Roboflow(api_key=YOUR_API_KEY_HERE)

# List all projects for your workspace
workspace = rf.workspace()
workspace.list_projects()
# Out:
# loading Roboflow workspace...
# [{'id': 'stormdamagechallenge/dsc24-building-type-object-detection-rlbsq', 'type': 'object-detection', 'name': 'DSC24 Building Type Object Detection', 'created': 1708707682.093, 'updated': 1752404477.872, 'images': 84, 'unannotated': -21, 'annotation': 'buildings-uui5', 'versions': 1, 'public': True, 'multilabel': False, 'license': 'CC BY 4.0', 'splits': {'valid': 20, 'test': 0, 'train': 64}, 'colors': {'damagedresidentialbuilding': '#00FFCE', 'damagedcommercialbuilding': '#FF8000', 'undamagedresidentialbuilding': '#FE0056', 'undamagedcommercialbuilding': '#C7FC00', 'buildings': '#FF8000'}, 'classes': {'damagedcommercialbuilding': 248, 'damagedresidentialbuilding': 164, 'undamagedresidentialbuilding': 920, 'undamagedcommercialbuilding': 764}, 'icon': {'original': 'https://source.roboflow.com/zwgRlPUciRYXlJ6Gy8Xlwn3kL2s2/KsfVh3fyAQ1nNFXOjMLx/original.jpg', 'thumb': 'https://source.roboflow.com/zwgRlPUciRYXlJ6Gy8Xlwn3kL2s2/KsfVh3fyAQ1nNFXOjMLx/thumb.jpg', 'annotation': 'https://source.roboflow.com/zwgRlPUciRYXlJ6Gy8Xlwn3kL2s2/KsfVh3fyAQ1nNFXOjMLx/annotation-buildings-uui5.png'}, 'preprocessing': {}, 'augmentation': {}}, {'id': 'stormdamagechallenge/storm-damage-goe2a', 'type': 'object-detection', 'name': 'Storm Damage', 'created': 1734792239.213, 'updated': 1735024587.537, 'images': 109, 'unannotated': 0, 'annotation': 'buildings', 'versions': 9, 'public': True, 'multilabel': False, 'license': 'MIT', 'splits': {'train': 76, 'valid': 22, 'test': 11}, 'colors': {'32': '#00FFCE', 'buildings': '#C7FC00', 'undamagedresidentialbuilding': '#8622FF', 'undamagedcommercialbuilding': '#FE0056', 'n': '#FF8000', 'undamagedcommercialbuilding\\': '#00B7EB', 'd': '#FFFF00'}, 'classes': {'32': 0, 'buildings': 0, 'undamagedcommercialbuilding\\': 0, 'n': 0, 'undamagedcommercialbuilding': 365, 'd': 0, 'undamagedresidentialbuilding': 2189}, 'icon': {'original': 'https://source.roboflow.com/zwgRlPUciRYXlJ6Gy8Xlwn3kL2s2/NglOYP9Ks9dvya98yg5d/original.jpg', 'thumb': 'https://source.roboflow.com/zwgRlPUciRYXlJ6Gy8Xlwn3kL2s2/NglOYP9Ks9dvya98yg5d/thumb.jpg', 'annotation': None}, 'preprocessing': {}, 'augmentation': {}}]

# %%
# Downloading dataset from Roboflow platform (Notice: after execution data will be deleted from google colab)
roboflow_project_name = 'dsc24-building-type-object-detection-rlbsq'
project_name = 'DSC24 Building Type Object Detection'
dataset_name = 'inspiration_dataset_v1.0.0'
dataset_title = 'inspiration_dataset_v1.0.0'
dataset_id = 'goe2a'
dataset_version = 1
model_name = 'yolo'
model_version = '11' # 'v8' or '11'
model_variant = 'n' # parameter required for model training phase

# Connect to roboflow dataset
project = rf.workspace().project(roboflow_project_name)
dataset = project.version(dataset_version).download(model_name + model_version)
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
#
# Version export complete for yolo11 format
# Downloading Dataset Version Zip in DSC24-Building-Type-Object-Detection-1 to yolo11:: 100%|██████████| 4276/4276 [00:00<00:00, 13067.41it/s]
# Extracting Dataset Version Zip to DSC24-Building-Type-Object-Detection-1 in yolo11:: 100%|██████████| 177/177 [00:00<00:00, 7179.32it/s]

# %%
import torch

# Supress Warnings
import warnings
warnings.filterwarnings('ignore')

# GeoTiff Images
import rasterio
from osgeo import gdal

# Visualisation
from matplotlib import pyplot as plt
import matplotlib.image as img
from matplotlib.pyplot import figure
from PIL import Image

# Model Building
import ultralytics
from ultralytics import YOLO
from IPython.display import Image

# Progress bar
from tqdm import tqdm

import numpy as np

# Others
import os
import shutil
import zipfile

# %matplotlib inline
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
ultralytics.checks()
# Out:
# Ultralytics 8.3.165 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 42.0/112.6 GB disk)

# %%
print(torch.cuda.is_available())
print(torch.cuda.device_count())
# Out:
# True
# 1

# %%
# !nvidia-smi
# Out:
# Sun Jul 13 12:05:26 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8             10W /   70W |       2MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# Loading the model
model = YOLO(f'../models/{model_name + model_version}/{model_name + model_version + model_variant}.pt')
# Display model information (optional)
model.info()
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to '../models/yolo11/yolo11n.pt'...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 97.0MB/s]
# YOLO11n summary: 181 layers, 2,624,080 parameters, 0 gradients, 6.6 GFLOPs
# (181, 2624080, 0, 6.614336)

# %%
yaml_file = f'{HOME}/DSC24-Building-Type-Object-Detection-1/data.yaml'
yaml_file
# Out:
# '/content/DSC24-Building-Type-Object-Detection-1/data.yaml'

# %%
# Define model training parameters
batch = -1 # set as an integer (e.g., batch=16), auto mode for 60% GPU memory utilization (batch=-1), or auto mode with specified utilization fraction (batch=0.70)
device = 0 # 0: GPU | 'cpu': cpu | 'mps': apple silicon mps
epochs = 50
patience = 10
imgsz = 640 # TODO: assess the importance of image size 640x640 by-design of Yolo models, image size role
plots = True
project = 'inspiration_dataset_exploration' # parent directory name
name_train = f'{model_name + model_version + model_variant}_training_dataset_v{dataset_version}_' # run directory name

# %%
# Train the model
result_model_training = model.train(
                                    data=yaml_file,
                                    batch = batch,
                                    device = device,
                                    epochs = epochs,
                                    patience = patience,
                                    imgsz = imgsz,
                                    # optimizer = 'AdamW',
                                    # lr0 = 2.5e-4,
                                    # momentum = 0.9,
                                    plots = plots,
                                    project = project,
                                    name = name_train
                                    )
# Out:
# Ultralytics 8.3.165 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=-1, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/DSC24-Building-Type-Object-Detection-1/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=../models/yolo11/yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolo11n_training_dataset_v1_, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=inspiration_dataset_exploration, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=inspiration_dataset_exploration/yolo11n_training_dataset_v1_, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100%|██████████| 755k/755k [00:00<00:00, 21.4MB/s]
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    431452  ultralytics.nn.modules.head.Detect           [4, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,590,620 parameters, 2,590,604 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 105MB/s]
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1214.8±590.4 MB/s, size: 48.0 KB)
# train: Scanning /content/DSC24-Building-Type-Object-Detection-1/train/labels... 64 images, 0 backgrounds, 0 corrupt: 100%|██████████| 64/64 [00:00<00:00, 1766.86it/s]
# train: New cache created: /content/DSC24-Building-Type-Object-Detection-1/train/labels.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 53, len(boxes) = 1529. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# AutoBatch: Computing optimal batch size for imgsz=640 at 60.0% CUDA memory utilization.
# AutoBatch: CUDA:0 (Tesla T4) 14.74G total, 0.10G reserved, 0.07G allocated, 14.57G free
#       Params      GFLOPs  GPU_mem (GB)  forward (ms) backward (ms)                   input                  output
#      2590620       6.444         0.463         65.89         298.7        (1, 3, 640, 640)                    list
#      2590620       12.89         0.631         32.44           117        (2, 3, 640, 640)                    list
#      2590620       25.78         0.942         34.32         106.2        (4, 3, 640, 640)                    list
#      2590620       51.55         1.604         37.22         117.2        (8, 3, 640, 640)                    list
#      2590620       103.1         2.877         54.04         128.4       (16, 3, 640, 640)                    list
# AutoBatch: Using batch-size 54 for CUDA:0 9.17G/14.74G (62%) ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1310.9±381.8 MB/s, size: 50.9 KB)
# train: Scanning /content/DSC24-Building-Type-Object-Detection-1/train/labels.cache... 64 images, 0 backgrounds, 0 corrupt: 100%|██████████| 64/64 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 53, len(boxes) = 1529. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 269.2±98.0 MB/s, size: 51.8 KB)
# val: Scanning /content/DSC24-Building-Type-Object-Detection-1/valid/labels... 20 images, 0 backgrounds, 0 corrupt: 100%|██████████| 20/20 [00:00<00:00, 1483.27it/s]
# val: New cache created: /content/DSC24-Building-Type-Object-Detection-1/valid/labels.cache
# Plotting labels to inspiration_dataset_exploration/yolo11n_training_dataset_v1_/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.000421875), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to inspiration_dataset_exploration/yolo11n_training_dataset_v1_
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      8.12G      2.023      4.006      1.757        220        640: 100%|██████████| 2/2 [00:02<00:00,  1.21s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:02<00:00,  2.13s/it]
#                    all         20        567    0.00123     0.0139    0.00075    0.00024
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50       7.7G      2.006      4.018      1.727        253        640: 100%|██████████| 2/2 [00:01<00:00,  1.75it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  3.98it/s]
#                    all         20        567    0.00143     0.0169   0.000779   0.000218
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      7.83G       1.98      4.056      1.728        285        640: 100%|██████████| 2/2 [00:01<00:00,  1.82it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  3.74it/s]
#                    all         20        567    0.00143     0.0183   0.000792   0.000247
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      7.77G      1.911      3.969      1.761        316        640: 100%|██████████| 2/2 [00:00<00:00,  2.16it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  5.04it/s]
#                    all         20        567    0.00172     0.0225   0.000985   0.000272
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      7.77G      1.752      3.988      1.488        404        640: 100%|██████████| 2/2 [00:00<00:00,  2.30it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  4.01it/s]
#                    all         20        567    0.00195      0.025    0.00179    0.00051
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      7.95G        1.6      3.821       1.42        299        640: 100%|██████████| 2/2 [00:01<00:00,  1.85it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  3.13it/s]
#                    all         20        567    0.00429      0.051    0.00562    0.00244
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      7.48G      1.522      3.699       1.35        329        640: 100%|██████████| 2/2 [00:01<00:00,  1.58it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  4.44it/s]
#                    all         20        567    0.00956     0.0796     0.0087    0.00431
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      7.49G      1.421      3.602      1.263        351        640: 100%|██████████| 2/2 [00:00<00:00,  2.08it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  4.87it/s]
#                    all         20        567     0.0173      0.114     0.0223     0.0106
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      8.09G      1.364      3.436      1.231        224        640: 100%|██████████| 2/2 [00:00<00:00,  2.17it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  4.49it/s]
#                    all         20        567     0.0313      0.194     0.0517     0.0283
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      7.72G      1.374      3.359       1.19        199        640: 100%|██████████| 2/2 [00:00<00:00,  2.30it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  4.18it/s]
#                    all         20        567     0.0455      0.334     0.0919     0.0482
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      7.76G      1.384      3.327      1.181        357        640: 100%|██████████| 2/2 [00:00<00:00,  2.27it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  4.32it/s]
#                    all         20        567     0.0522      0.457       0.13     0.0709
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      7.74G      1.384      3.297      1.179        516        640: 100%|██████████| 2/2 [00:00<00:00,  2.21it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  2.58it/s]
#                    all         20        567     0.0559       0.54      0.153     0.0826
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      7.72G      1.444      3.054       1.23        310        640: 100%|██████████| 2/2 [00:01<00:00,  1.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  3.58it/s]
#                    all         20        567     0.0595      0.607      0.164     0.0911
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      7.89G      1.452      2.891      1.256        224        640: 100%|██████████| 2/2 [00:00<00:00,  2.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  4.38it/s]
#                    all         20        567     0.0578      0.601      0.163     0.0884
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      7.76G      1.404      2.828      1.163        335        640: 100%|██████████| 2/2 [00:00<00:00,  2.05it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  4.33it/s]
#                    all         20        567     0.0593       0.61       0.17     0.0934
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      7.75G      1.416      2.725      1.194        338        640: 100%|██████████| 2/2 [00:00<00:00,  2.14it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  4.97it/s]
#                    all         20        567     0.0598      0.606      0.173     0.0949
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      7.99G      1.364      2.713      1.163        428        640: 100%|██████████| 2/2 [00:01<00:00,  1.97it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  4.50it/s]
#                    all         20        567     0.0612      0.606      0.175     0.0979
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50      7.86G      1.408      2.536      1.187        334        640: 100%|██████████| 2/2 [00:00<00:00,  2.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  3.19it/s]
#                    all         20        567     0.0617      0.599       0.17        0.1
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50      7.78G      1.408      2.484      1.205        348        640: 100%|██████████| 2/2 [00:01<00:00,  1.67it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  3.38it/s]
#                    all         20        567     0.0619      0.596      0.167      0.093
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      7.67G      1.411      2.403      1.223        249        640: 100%|██████████| 2/2 [00:00<00:00,  2.11it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  4.69it/s]
#                    all         20        567     0.0618      0.606      0.166     0.0857
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50      7.92G      1.451      2.467      1.225        510        640: 100%|██████████| 2/2 [00:01<00:00,  1.99it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  4.86it/s]
#                    all         20        567     0.0587      0.575      0.155     0.0873
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50      7.65G      1.357      2.252      1.165        310        640: 100%|██████████| 2/2 [00:00<00:00,  2.25it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  4.19it/s]
#                    all         20        567     0.0575      0.567      0.157     0.0912
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50      7.56G      1.394      2.255       1.23        311        640: 100%|██████████| 2/2 [00:00<00:00,  2.19it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  4.38it/s]
#                    all         20        567     0.0584      0.594      0.166      0.088
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50      8.11G      1.404      2.158       1.21        251        640: 100%|██████████| 2/2 [00:00<00:00,  2.08it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  2.68it/s]
#                    all         20        567     0.0599      0.612      0.168     0.0881
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50      7.99G      1.321      2.129      1.207        217        640: 100%|██████████| 2/2 [00:01<00:00,  1.67it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  2.85it/s]
#                    all         20        567       0.06      0.613      0.171     0.0971
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50      7.92G       1.31      2.061      1.177        319        640: 100%|██████████| 2/2 [00:00<00:00,  2.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  4.80it/s]
#                    all         20        567     0.0604      0.609      0.174     0.0991
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      7.72G      1.376      2.087      1.191        399        640: 100%|██████████| 2/2 [00:00<00:00,  2.24it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  4.17it/s]
#                    all         20        567     0.0573      0.574      0.165     0.0933
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50      8.03G      1.363       2.04      1.222        311        640: 100%|██████████| 2/2 [00:00<00:00,  2.07it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  4.79it/s]
#                    all         20        567     0.0502      0.482      0.144     0.0801
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 18, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
# 28 epochs completed in 0.018 hours.
# Optimizer stripped from inspiration_dataset_exploration/yolo11n_training_dataset_v1_/weights/last.pt, 5.5MB
# Optimizer stripped from inspiration_dataset_exploration/yolo11n_training_dataset_v1_/weights/best.pt, 5.5MB
#
# Validating inspiration_dataset_exploration/yolo11n_training_dataset_v1_/weights/best.pt...
# Ultralytics 8.3.165 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,582,932 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  4.90it/s]
#                    all         20        567     0.0615      0.597       0.17     0.0999
# damagedcommercialbuilding         17         84     0.0344      0.512     0.0619     0.0361
# damagedresidentialbuilding         16         51     0.0362       0.51       0.04      0.021
# undamagedcommercialbuilding         20        200     0.0476       0.65       0.24       0.13
# undamagedresidentialbuilding         20        232      0.128      0.716      0.336      0.212
# Speed: 0.3ms preprocess, 2.1ms inference, 0.0ms loss, 1.9ms postprocess per image
# Results saved to inspiration_dataset_exploration/yolo11n_training_dataset_v1_

# %%
# %cd {HOME}
Image(filename=f'{HOME}/{project}/{name_train}/results.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/{project}/{name_train}/confusion_matrix_normalized.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/{project}/{name_train}/confusion_matrix.png', width=600)
# Out:
# /content
